# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
model.compile(optimizer=Adam(),
              loss=SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9283 - loss: 0.2521
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9683 - loss: 0.1084
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9771 - loss: 0.0760
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0572
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9863 - loss: 0.0433
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9890 - loss: 0.0349
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9914 - loss: 0.0280
# Epoch 8/10
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
accuracy_score = accuracy_score(y_test, y_pred.argmax(axis=1))
print(accuracy_score)
confu = confusion_matrix(y_test, y_pred.argmax(axis=1))
ConfusionMatrixDisplay(confu).plot()
print(confu)
# Out:
# 0.9787
# [[ 969    1    2    0    1    1    4    1    1    0]
#  [   0 1128    3    0    0    1    2    1    0    0]
#  [   7    2 1003    2    2    0    2    9    5    0]
#  [   0    0    5  989    0    5    0    5    3    3]
#  [   2    2    2    0  957    0    5    2    0   12]
#  [   2    0    0    4    1  874    6    1    4    0]
#  [   3    2    0    0    2    3  947    1    0    0]
#  [   1    6    7    1    1    0    0 1003    1    8]
#  [   2    1    5    5    1    7    2    5  943    3]
#  [   3    4    0    5   11    2    0    8    2  974]]

# %%
score = accuracy_score(y_test, y_pred.argmax(axis=1))
score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 score = accuracy_score(y_test, y_pred.argmax(axis=1))
#       2 score
#
# TypeError: 'float' object is not callable

# %%
print(confu)
# Out:
# [[ 969    1    2    0    1    1    4    1    1    0]
#  [   0 1128    3    0    0    1    2    1    0    0]
#  [   7    2 1003    2    2    0    2    9    5    0]
#  [   0    0    5  989    0    5    0    5    3    3]
#  [   2    2    2    0  957    0    5    2    0   12]
#  [   2    0    0    4    1  874    6    1    4    0]
#  [   3    2    0    0    2    3  947    1    0    0]
#  [   1    6    7    1    1    0    0 1003    1    8]
#  [   2    1    5    5    1    7    2    5  943    3]
#  [   3    4    0    5   11    2    0    8    2  974]]

# %%
## check different neurons in hidden layer and comare its accuracy and confusion matrix
for neurons in [64, 128, 256, 512]:
    print(f'Training model with {neurons} neurons in the hidden layer')
    model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(neurons, activation='relu'),
    Dense(10, activation='softmax')
    ])
    model.compile(optimizer=Adam(),
                loss=SparseCategoricalCrossentropy(),
                metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=5)
    y_pred = model.predict(x_test)
    y_pred_classes = y_pred.argmax(axis=1)  # convert probability matrix → class labels

    acc = accuracy_score(y_test, y_pred_classes)
    print(f'Accuracy with {neurons} neurons: {acc:.4f}')
    confu = confusion_matrix(y_test, y_pred_classes)
    ConfusionMatrixDisplay(confu).plot(cmap='Blues')
    plt.title(f'Confusion Matrix ({neurons} neurons)')
    plt.show()
# Out:
# Training model with 64 neurons in the hidden layer
# Epoch 1/5
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9171 - loss: 0.2972
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9588 - loss: 0.1420
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9697 - loss: 0.1034
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9760 - loss: 0.0807
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9801 - loss: 0.0669
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# Accuracy with 64 neurons: 0.9715
# Training model with 128 neurons in the hidden layer
# Epoch 1/5
# ...
